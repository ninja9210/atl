# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
plt.rcParams['figure.figsize'] = (12,6)

# %%
data = pd.read_csv("Phishing_Legitimate_full.csv")
float_cols = data.select_dtypes('float64').columns
for c in float_cols:
    data[c] = data[c].astype('float32')
int_cols = data.select_dtypes('int64').columns
for c in int_cols:
    data[c] = data[c].astype('int32')
    data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int64
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(1), int64(46)
# memory usage: 3.7 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int64
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(2), int64(45)
# memory usage: 3.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int64
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(3), int64(44)
# memory usage: 3.6 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int64
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(4), int64(43)
# memory usage: 3.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int64
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(5), int64(42)
# memory usage: 3.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int64
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(6), int64(41)
# memory usage: 3.5 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int64
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(7), int64(40)
# memory usage: 3.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int64
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(8), int64(39)
# memory usage: 3.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int64
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(9), int64(38)
# memory usage: 3.4 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int64
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(10), int64(37)
# memory usage: 3.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int64
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(11), int64(36)
# memory usage: 3.3 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int64
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(12), int64(35)
# memory usage: 3.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int64
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
#  24  DoubleSlashInPath                   10000 non-null  int64
#  25  NumSensitiveWords                   10000 non-null  int64
#  26  EmbeddedBrandName                   10000 non-null  int64
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int64
#  30  InsecureForms                       10000 non-null  int64
#  31  RelativeFormAction                  10000 non-null  int64
#  32  ExtFormAction                       10000 non-null  int64
#  33  AbnormalFormAction                  10000 non-null  int64
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int64
#  36  FakeLinkInStatusBar                 10000 non-null  int64
#  37  RightClickDisabled                  10000 non-null  int64
#  38  PopUpWindow                         10000 non-null  int64
#  39  SubmitInfoToEmail                   10000 non-null  int64
#  40  IframeOrFrame                       10000 non-null  int64
#  41  MissingTitle                        10000 non-null  int64
#  42  ImagesOnlyInForm                    10000 non-null  int64
#  43  SubdomainLevelRT                    10000 non-null  int64
#  44  UrlLengthRT                         10000 non-null  int64
#  45  PctExtResourceUrlsRT                10000 non-null  int64
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(13), int64(34)
# memory usage: 3.2 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int64
#  15  NoHttps                             10000 non-null  int64
#  16  RandomString                        10000 non-null  int64
#  17  IpAddress                           10000 non-null  int64
#  18  DomainInSubdomains                  10000 non-null  int64
#  19  DomainInPaths                       10000 non-null  int64
#  20  HttpsInHostname                     10000 non-null  int64
#  21  HostnameLength                      10000 non-null  int64
#  22  PathLength                          10000 non-null  int64
#  23  QueryLength                         10000 non-null  int64
# ...
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int64
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(43), int64(4)
# memory usage: 2.1 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int64
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(44), int64(3)
# memory usage: 2.0 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int64
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(45), int64(2)
# memory usage: 2.0 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  49  CLASS_LABEL                         10000 non-null  int64
# dtypes: float32(3), int32(46), int64(1)
# memory usage: 1.9 MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 50 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  10000 non-null  int32
#  1   NumDots                             10000 non-null  int32
#  2   SubdomainLevel                      10000 non-null  int32
#  3   PathLevel                           10000 non-null  int32
#  4   UrlLength                           10000 non-null  int32
#  5   NumDash                             10000 non-null  int32
#  6   NumDashInHostname                   10000 non-null  int32
#  7   AtSymbol                            10000 non-null  int32
#  8   TildeSymbol                         10000 non-null  int32
#  9   NumUnderscore                       10000 non-null  int32
#  10  NumPercent                          10000 non-null  int32
#  11  NumQueryComponents                  10000 non-null  int32
#  12  NumAmpersand                        10000 non-null  int32
#  13  NumHash                             10000 non-null  int32
#  14  NumNumericChars                     10000 non-null  int32
#  15  NoHttps                             10000 non-null  int32
#  16  RandomString                        10000 non-null  int32
#  17  IpAddress                           10000 non-null  int32
#  18  DomainInSubdomains                  10000 non-null  int32
#  19  DomainInPaths                       10000 non-null  int32
#  20  HttpsInHostname                     10000 non-null  int32
#  21  HostnameLength                      10000 non-null  int32
#  22  PathLength                          10000 non-null  int32
#  23  QueryLength                         10000 non-null  int32
#  24  DoubleSlashInPath                   10000 non-null  int32
#  25  NumSensitiveWords                   10000 non-null  int32
#  26  EmbeddedBrandName                   10000 non-null  int32
#  27  PctExtHyperlinks                    10000 non-null  float32
#  28  PctExtResourceUrls                  10000 non-null  float32
#  29  ExtFavicon                          10000 non-null  int32
#  30  InsecureForms                       10000 non-null  int32
#  31  RelativeFormAction                  10000 non-null  int32
#  32  ExtFormAction                       10000 non-null  int32
#  33  AbnormalFormAction                  10000 non-null  int32
#  34  PctNullSelfRedirectHyperlinks       10000 non-null  float32
#  35  FrequentDomainNameMismatch          10000 non-null  int32
#  36  FakeLinkInStatusBar                 10000 non-null  int32
#  37  RightClickDisabled                  10000 non-null  int32
#  38  PopUpWindow                         10000 non-null  int32
#  39  SubmitInfoToEmail                   10000 non-null  int32
#  40  IframeOrFrame                       10000 non-null  int32
#  41  MissingTitle                        10000 non-null  int32
#  42  ImagesOnlyInForm                    10000 non-null  int32
#  43  SubdomainLevelRT                    10000 non-null  int32
#  44  UrlLengthRT                         10000 non-null  int32
#  45  PctExtResourceUrlsRT                10000 non-null  int32
#  46  AbnormalExtFormActionR              10000 non-null  int32
#  47  ExtMetaScriptLinkRT                 10000 non-null  int32
#  48  PctExtNullSelfRedirectHyperlinksRT  10000 non-null  int32
#  49  CLASS_LABEL                         10000 non-null  int32
# dtypes: float32(3), int32(47)
# memory usage: 1.9 MB

# %%
data.rename(columns={'CLASS_LABEL': 'labels'}, inplace=True)
data.sample(5)
# Out:
#         id  NumDots  SubdomainLevel  PathLevel  UrlLength  NumDash  \
# 6934  6935        2               0          2        129        3
# 5026  5027        1               0          0         17        0
# 6680  6681        2               1          5         64        5
# 2880  2881        2               0          4         60        1
# 3020  3021        2               1          3         42        0
#
#       NumDashInHostname  AtSymbol  TildeSymbol  NumUnderscore  NumPercent  \
# 6934                  0         0            0              0           8
# 5026                  0         0            0              0           0
# 6680                  0         0            0              0           0
# 2880                  0         0            0              1           0
# 3020                  0         0            0              0           0
#
#       NumQueryComponents  NumAmpersand  NumHash  NumNumericChars  NoHttps  \
# 6934                   2             1        0               15        1
# 5026                   0             0        0                0        1
# 6680                   0             0        0               20        1
# 2880                   0             0        0                0        1
# 3020                   0             0        0                0        1
#
#       RandomString  IpAddress  DomainInSubdomains  DomainInPaths  \
# 6934             0          0                   0              0
# 5026             0          0                   0              0
# 6680             1          0                   0              0
# 2880             1          0                   0              1
# 3020             0          0                   0              0
#
#       HttpsInHostname  HostnameLength  PathLength  QueryLength  \
# 6934                0              13           7          101
# 5026                0               9           1            0
# 6680                0              21          36            0
# 2880                0               9          44            0
# 3020                0              21          14            0
#
#       DoubleSlashInPath  NumSensitiveWords  EmbeddedBrandName  \
# 6934                  0                  0                  0
# 5026                  0                  0                  0
# 6680                  0                  0                  0
# 2880                  0                  0                  0
# 3020                  0                  0                  0
#
#       PctExtHyperlinks  PctExtResourceUrls  ExtFavicon  InsecureForms  \
# 6934          0.343949            0.600000           0              1
# 5026          0.009346            0.061728           0              1
# 6680          0.048193            0.333333           0              1
# 2880          0.000000            0.000000           0              1
# 3020          0.000000            0.000000           0              1
#
#       RelativeFormAction  ExtFormAction  AbnormalFormAction  \
# 6934                   0              0                   0
# 5026                   1              0                   0
# 6680                   0              0                   0
# 2880                   0              0                   0
# 3020                   0              0                   0
#
#       PctNullSelfRedirectHyperlinks  FrequentDomainNameMismatch  \
# 6934                       0.000000                           0
# 5026                       0.009346                           0
# 6680                       0.012048                           0
# 2880                       0.000000                           1
# 3020                       0.000000                           0
#
#       FakeLinkInStatusBar  RightClickDisabled  PopUpWindow  SubmitInfoToEmail  \
# 6934                    0                   0            0                  0
# 5026                    0                   0            0                  0
# 6680                    0                   0            0                  0
# 2880                    0                   0            0                  0
# 3020                    0                   0            0                  0
#
#       IframeOrFrame  MissingTitle  ImagesOnlyInForm  SubdomainLevelRT  \
# 6934              1             0                 0                 1
# 5026              1             0                 0                 1
# 6680              0             0                 0                 1
# 2880              0             0                 0                 1
# 3020              0             0                 0                 1
#
#       UrlLengthRT  PctExtResourceUrlsRT  AbnormalExtFormActionR  \
# 6934           -1                    -1                       1
# 5026            1                     1                       1
# 6680            0                     1                       1
# 2880            0                     1                       1
# 3020            1                     1                       1
#
#       ExtMetaScriptLinkRT  PctExtNullSelfRedirectHyperlinksRT  labels
# 6934                    0                                   0       0
# 5026                    0                                   1       0
# 6680                    0                                   1       0
# 2880                    1                                   1       1
# 3020                    1                                   1       1

# %%
data.describe()
# Out:
#                 id       NumDots  SubdomainLevel     PathLevel     UrlLength  \
# count  10000.00000  10000.000000    10000.000000  10000.000000  10000.000000
# mean    5000.50000      2.445100        0.586800      3.300300     70.264100
# std     2886.89568      1.346836        0.751214      1.863241     33.369877
# min        1.00000      1.000000        0.000000      0.000000     12.000000
# 25%     2500.75000      2.000000        0.000000      2.000000     48.000000
# 50%     5000.50000      2.000000        1.000000      3.000000     62.000000
# 75%     7500.25000      3.000000        1.000000      4.000000     84.000000
# max    10000.00000     21.000000       14.000000     18.000000    253.000000
#
#             NumDash  NumDashInHostname      AtSymbol   TildeSymbol  \
# count  10000.000000       10000.000000  10000.000000  10000.000000
# mean       1.818000           0.138900      0.000300      0.013100
# std        3.106258           0.545744      0.017319      0.113709
# min        0.000000           0.000000      0.000000      0.000000
# 25%        0.000000           0.000000      0.000000      0.000000
# 50%        0.000000           0.000000      0.000000      0.000000
# 75%        2.000000           0.000000      0.000000      0.000000
# max       55.000000           9.000000      1.000000      1.000000
#
#        NumUnderscore    NumPercent  NumQueryComponents  NumAmpersand  \
# count    10000.00000  10000.000000        10000.000000  10000.000000
# mean         0.32320      0.073800            0.458600      0.277200
# std          1.11466      0.622248            1.344793      1.117356
# min          0.00000      0.000000            0.000000      0.000000
# 25%          0.00000      0.000000            0.000000      0.000000
# 50%          0.00000      0.000000            0.000000      0.000000
# 75%          0.00000      0.000000            0.000000      0.000000
# max         18.00000     19.000000           23.000000     22.000000
#
#             NumHash  NumNumericChars       NoHttps  RandomString  \
# count  10000.000000     10000.000000  10000.000000   10000.00000
# mean       0.002300         5.810300      0.988800       0.52520
# std        0.047906         9.617877      0.105241       0.49939
# min        0.000000         0.000000      0.000000       0.00000
# 25%        0.000000         0.000000      1.000000       0.00000
# 50%        0.000000         2.000000      1.000000       1.00000
# 75%        0.000000         8.000000      1.000000       1.00000
# max        1.000000       111.000000      1.000000       1.00000
#
#           IpAddress  DomainInSubdomains  DomainInPaths  HttpsInHostname  \
# count  10000.000000        10000.000000   10000.000000          10000.0
# mean       0.017200            0.022200       0.428900              0.0
# std        0.130023            0.147341       0.494944              0.0
# min        0.000000            0.000000       0.000000              0.0
# 25%        0.000000            0.000000       0.000000              0.0
# 50%        0.000000            0.000000       0.000000              0.0
# 75%        0.000000            0.000000       1.000000              0.0
# max        1.000000            1.000000       1.000000              0.0
#
#        HostnameLength    PathLength   QueryLength  DoubleSlashInPath  \
# count     10000.00000  10000.000000  10000.000000       10000.000000
# mean         18.82430     35.564900      8.606500           0.000900
# std           8.11654     24.588502     24.313053           0.029988
# min           4.00000      0.000000      0.000000           0.000000
# 25%          14.00000     18.000000      0.000000           0.000000
# 50%          18.00000     30.000000      0.000000           0.000000
# 75%          22.00000     48.000000      0.000000           0.000000
# max         137.00000    161.000000    188.000000           1.000000
#
#        NumSensitiveWords  EmbeddedBrandName  PctExtHyperlinks  \
# count       10000.000000       10000.000000      10000.000000
# mean            0.109300           0.057100          0.241334
# std             0.368737           0.232045          0.342370
# min             0.000000           0.000000          0.000000
# 25%             0.000000           0.000000          0.000000
# 50%             0.000000           0.000000          0.071429
# 75%             0.000000           0.000000          0.315874
# max             3.000000           1.000000          1.000000
#
#        PctExtResourceUrls    ExtFavicon  InsecureForms  RelativeFormAction  \
# count        10000.000000  10000.000000   10000.000000        10000.000000
# mean             0.392932      0.167200       0.844000            0.248700
# std              0.387292      0.373173       0.362873            0.432281
# min              0.000000      0.000000       0.000000            0.000000
# 25%              0.030303      0.000000       1.000000            0.000000
# 50%              0.247511      0.000000       1.000000            0.000000
# 75%              0.785714      0.000000       1.000000            0.000000
# max              1.000000      1.000000       1.000000            1.000000
#
#        ExtFormAction  AbnormalFormAction  PctNullSelfRedirectHyperlinks  \
# count     10000.0000        10000.000000                   10000.000000
# mean          0.1018            0.057600                       0.136136
# std           0.3024            0.232997                       0.312413
# min           0.0000            0.000000                       0.000000
# 25%           0.0000            0.000000                       0.000000
# 50%           0.0000            0.000000                       0.000000
# 75%           0.0000            0.000000                       0.047619
# max           1.0000            1.000000                       1.000000
#
#        FrequentDomainNameMismatch  FakeLinkInStatusBar  RightClickDisabled  \
# count                10000.000000         10000.000000        10000.000000
# mean                     0.215300             0.005500            0.014000
# std                      0.411051             0.073961            0.117496
# min                      0.000000             0.000000            0.000000
# 25%                      0.000000             0.000000            0.000000
# 50%                      0.000000             0.000000            0.000000
# 75%                      0.000000             0.000000            0.000000
# max                      1.000000             1.000000            1.000000
#
#         PopUpWindow  SubmitInfoToEmail  IframeOrFrame  MissingTitle  \
# count  10000.000000       10000.000000   10000.000000   10000.00000
# mean       0.004900           0.128800       0.339600       0.03220
# std        0.069832           0.334995       0.473597       0.17654
# min        0.000000           0.000000       0.000000       0.00000
# 25%        0.000000           0.000000       0.000000       0.00000
# 50%        0.000000           0.000000       0.000000       0.00000
# 75%        0.000000           0.000000       1.000000       0.00000
# max        1.000000           1.000000       1.000000       1.00000
#
#        ImagesOnlyInForm  SubdomainLevelRT   UrlLengthRT  PctExtResourceUrlsRT  \
# count      10000.000000      10000.000000  10000.000000          10000.000000
# mean           0.030400          0.956600      0.020200              0.353300
# std            0.171694          0.248037      0.820036              0.888908
# min            0.000000         -1.000000     -1.000000             -1.000000
# 25%            0.000000          1.000000     -1.000000             -1.000000
# 50%            0.000000          1.000000      0.000000              1.000000
# 75%            0.000000          1.000000      1.000000              1.000000
# max            1.000000          1.000000      1.000000              1.000000
#
#        AbnormalExtFormActionR  ExtMetaScriptLinkRT  \
# count            10000.000000         10000.000000
# mean                 0.793200             0.173400
# std                  0.521019             0.755771
# min                 -1.000000            -1.000000
# 25%                  1.000000             0.000000
# 50%                  1.000000             0.000000
# 75%                  1.000000             1.000000
# max                  1.000000             1.000000
#
#        PctExtNullSelfRedirectHyperlinksRT        labels
# count                        10000.000000  10000.000000
# mean                             0.314100      0.500000
# std                              0.897843      0.500025
# min                             -1.000000      0.000000
# 25%                             -1.000000      0.000000
# 50%                              1.000000      0.500000
# 75%                              1.000000      1.000000
# max                              1.000000      1.000000

# %%
data['labels'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='labels'>

# %%
def corr_heatmap(data, idx_s, idx_e):
    y = data['labels']
    temp = data.iloc[:, idx_s:idx_e]
    if 'id' in temp.columns:
        del temp['id']
    temp['labels'] = y
    sns.heatmap(temp.corr(), annot=True, fmt='.2f')
    plt.show()
corr_heatmap(data, 0, 10)

# %%
corr_heatmap(data, 10, 20)

# %%
corr_heatmap(data, 20, 30)

# %%
corr_heatmap(data, 30, 40)

# %%
corr_heatmap(data, 40, 50)

# %%
from sklearn.feature_selection import mutual_info_classif
X = data.drop(['id', 'labels'], axis=1)
y = data['labels']
discrete_features = X.dtypes == int
mi_scores = mutual_info_classif(X, y, discrete_features=discrete_features)
mi_scores = pd.Series(mi_scores, name='MI Scores', index=X.columns)
mi_scores = mi_scores.sort_values(ascending=False)
mi_scores
# Out:
# PctExtHyperlinks                      4.638318e-01
# PctExtResourceUrls                    2.960930e-01
# PctNullSelfRedirectHyperlinks         2.331113e-01
# PctExtNullSelfRedirectHyperlinksRT    2.123850e-01
# NumNumericChars                       1.326711e-01
# FrequentDomainNameMismatch            1.254908e-01
# ExtMetaScriptLinkRT                   1.175434e-01
# NumDash                               1.140136e-01
# SubmitInfoToEmail                     7.802617e-02
# NumDots                               6.553700e-02
# PathLength                            6.413269e-02
# QueryLength                           5.818557e-02
# PathLevel                             5.543887e-02
# InsecureForms                         5.508096e-02
# UrlLength                             5.263855e-02
# NumSensitiveWords                     4.180522e-02
# NumQueryComponents                    3.361768e-02
# PctExtResourceUrlsRT                  2.831059e-02
# IframeOrFrame                         2.805496e-02
# HostnameLength                        2.564249e-02
# NumAmpersand                          1.962894e-02
# AbnormalExtFormActionR                1.816610e-02
# UrlLengthRT                           1.513853e-02
# NumDashInHostname                     1.502933e-02
# IpAddress                             1.207265e-02
# AbnormalFormAction                    1.118934e-02
# EmbeddedBrandName                     1.066208e-02
# NumUnderscore                         1.037366e-02
# MissingTitle                          7.353661e-03
# DomainInPaths                         7.003483e-03
# SubdomainLevel                        6.392610e-03
# ExtFormAction                         5.613946e-03
# DomainInSubdomains                    5.497419e-03
# TildeSymbol                           5.362924e-03
# SubdomainLevelRT                      4.503644e-03
# NumPercent                            3.790407e-03
# RandomString                          3.643235e-03
# RelativeFormAction                    3.419686e-03
# RightClickDisabled                    3.024050e-03
# PopUpWindow                           2.919366e-03
# NoHttps                               2.854909e-03
# ExtFavicon                            2.398229e-03
# NumHash                               1.596890e-03
# DoubleSlashInPath                     3.101288e-04
# AtSymbol                              2.079892e-04
# FakeLinkInStatusBar                   1.113537e-04
# ImagesOnlyInForm                      6.785265e-07
# HttpsInHostname                       0.000000e+00
# Name: MI Scores, dtype: float64

# %%
def plot_mi_scores(scores):
    scores = scores.sort_values(ascending=True)
    width = np.arange(len(scores))
    ticks = list(scores.index)
    plt.barh(width, scores)
    plt.yticks(width, ticks)
    plt.title("MI Scores")
    
plt.figure(dpi=100, figsize=(12,12))
plot_mi_scores(mi_scores)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score,f1_score

# %%
def train_logistic(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=True)

    lr = LogisticRegression(max_iter=10000)
    lr.fit(X_train, y_train)
    y_pred = lr.predict(X_test)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_logistic(data, i)
    print("Performance for Logistic Model with Top {} features is precision :{}, recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall,f1, accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for Logistic Model with Top 20 features is precision :0.9038652130822596, recall : 0.9363449691991786, f1 score : 0.9198184568835098, accuracy : 0.9205
# Performance for Logistic Model with Top 21 features is precision :0.9164265129682997, recall : 0.9380530973451328, f1 score : 0.9271137026239067, accuracy : 0.925
# Performance for Logistic Model with Top 22 features is precision :0.9198113207547169, recall : 0.9420289855072463, f1 score : 0.9307875894988067, accuracy : 0.9275
# Performance for Logistic Model with Top 23 features is precision :0.92725509214355, recall : 0.9437314906219151, f1 score : 0.9354207436399217, accuracy : 0.934
# Performance for Logistic Model with Top 24 features is precision :0.9374389051808406, recall : 0.930164888457808, f1 score : 0.9337877312560857, accuracy : 0.932
# Performance for Logistic Model with Top 25 features is precision :0.898238747553816, recall : 0.9473684210526315, f1 score : 0.922149673530889, accuracy : 0.9225
# Performance for Logistic Model with Top 26 features is precision :0.9187380497131931, recall : 0.9458661417322834, f1 score : 0.9321047526673133, accuracy : 0.93
# Performance for Logistic Model with Top 27 features is precision :0.9295336787564766, recall : 0.9452054794520548, f1 score : 0.9373040752351097, accuracy : 0.94
# Performance for Logistic Model with Top 28 features is precision :0.9271653543307087, recall : 0.9486404833836858, f1 score : 0.9377799900447984, accuracy : 0.9375
# Performance for Logistic Model with Top 29 features is precision :0.9168297455968689, recall : 0.9493414387031408, f1 score : 0.9328023892483823, accuracy : 0.9325
# Performance for Logistic Model with Top 30 features is precision :0.9302788844621513, recall : 0.934934934934935, f1 score : 0.9326010983524713, accuracy : 0.9325
# Performance for Logistic Model with Top 31 features is precision :0.9298780487804879, recall : 0.9403905447070915, f1 score : 0.9351047521716913, accuracy : 0.9365
# Performance for Logistic Model with Top 32 features is precision :0.9245837414299706, recall : 0.9383697813121272, f1 score : 0.9314257523433646, accuracy : 0.9305
# Performance for Logistic Model with Top 33 features is precision :0.9271991911021233, recall : 0.9443872296601442, f1 score : 0.9357142857142857, accuracy : 0.937
# Performance for Logistic Model with Top 34 features is precision :0.9223968565815324, recall : 0.945619335347432, f1 score : 0.9338637493784187, accuracy : 0.9335
# Performance for Logistic Model with Top 35 features is precision :0.9294003868471954, recall : 0.941234084231146, f1 score : 0.9352798053527981, accuracy : 0.9335
# Performance for Logistic Model with Top 36 features is precision :0.9252988047808764, recall : 0.9450661241098678, f1 score : 0.9350780070457977, accuracy : 0.9355
# Performance for Logistic Model with Top 37 features is precision :0.9419419419419419, recall : 0.9466800804828974, f1 score : 0.9443050677370798, accuracy : 0.9445
# Performance for Logistic Model with Top 38 features is precision :0.9239653512993262, recall : 0.947680157946693, f1 score : 0.935672514619883, accuracy : 0.934
# Performance for Logistic Model with Top 39 features is precision :0.9357976653696498, recall : 0.9385365853658536, f1 score : 0.9371651242084754, accuracy : 0.9355
# Performance for Logistic Model with Top 40 features is precision :0.9173228346456693, recall : 0.9510204081632653, f1 score : 0.9338677354709419, accuracy : 0.934
# Performance for Logistic Model with Top 41 features is precision :0.9286412512218963, recall : 0.9481037924151696, f1 score : 0.9382716049382716, accuracy : 0.9375
# Performance for Logistic Model with Top 42 features is precision :0.9348697394789579, recall : 0.9472081218274112, f1 score : 0.9409984871406959, accuracy : 0.9415
# Performance for Logistic Model with Top 43 features is precision :0.9448275862068966, recall : 0.9476284584980237, f1 score : 0.946225949679329, accuracy : 0.9455
# Performance for Logistic Model with Top 44 features is precision :0.9380952380952381, recall : 0.9591041869522883, f1 score : 0.9484833895040924, accuracy : 0.9465
# Performance for Logistic Model with Top 45 features is precision :0.9331366764995084, recall : 0.9452191235059761, f1 score : 0.9391390400791687, accuracy : 0.9385
# Performance for Logistic Model with Top 46 features is precision :0.9495548961424333, recall : 0.9375, f1 score : 0.9434889434889435, accuracy : 0.9425
# Performance for Logistic Model with Top 47 features is precision :0.9397473275024295, recall : 0.958374628344896, f1 score : 0.9489695780176644, accuracy : 0.948
# Performance for Logistic Model with Top 48 features is precision :0.9471624266144814, recall : 0.952755905511811, f1 score : 0.9499509322865555, accuracy : 0.949
# Performance for Logistic Model with Top 49 features is precision :0.9347826086956522, recall : 0.9469469469469469, f1 score : 0.9408254599701641, accuracy : 0.9405
# Performance for Logistic Model with Top 50 features is precision :0.9518768046198267, recall : 0.9601941747572815, f1 score : 0.9560173997100049, accuracy : 0.9545

# %%
df = pd.DataFrame(arr, columns=['num_of_features', 'precision', 'recall','f1_score', 'accuracy'])
df
# Out:
#     num_of_features  precision    recall  f1_score  accuracy
# 0                20   0.903865  0.936345  0.919818    0.9205
# 1                21   0.916427  0.938053  0.927114    0.9250
# 2                22   0.919811  0.942029  0.930788    0.9275
# 3                23   0.927255  0.943731  0.935421    0.9340
# 4                24   0.937439  0.930165  0.933788    0.9320
# 5                25   0.898239  0.947368  0.922150    0.9225
# 6                26   0.918738  0.945866  0.932105    0.9300
# 7                27   0.929534  0.945205  0.937304    0.9400
# 8                28   0.927165  0.948640  0.937780    0.9375
# 9                29   0.916830  0.949341  0.932802    0.9325
# 10               30   0.930279  0.934935  0.932601    0.9325
# 11               31   0.929878  0.940391  0.935105    0.9365
# 12               32   0.924584  0.938370  0.931426    0.9305
# 13               33   0.927199  0.944387  0.935714    0.9370
# 14               34   0.922397  0.945619  0.933864    0.9335
# 15               35   0.929400  0.941234  0.935280    0.9335
# 16               36   0.925299  0.945066  0.935078    0.9355
# 17               37   0.941942  0.946680  0.944305    0.9445
# 18               38   0.923965  0.947680  0.935673    0.9340
# 19               39   0.935798  0.938537  0.937165    0.9355
# 20               40   0.917323  0.951020  0.933868    0.9340
# 21               41   0.928641  0.948104  0.938272    0.9375
# 22               42   0.934870  0.947208  0.940998    0.9415
# 23               43   0.944828  0.947628  0.946226    0.9455
# 24               44   0.938095  0.959104  0.948483    0.9465
# 25               45   0.933137  0.945219  0.939139    0.9385
# 26               46   0.949555  0.937500  0.943489    0.9425
# 27               47   0.939747  0.958375  0.948970    0.9480
# 28               48   0.947162  0.952756  0.949951    0.9490
# 29               49   0.934783  0.946947  0.940825    0.9405
# 30               50   0.951877  0.960194  0.956017    0.9545

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='PrecisionScore')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
# Out:
# <Axes: xlabel='num_of_features', ylabel='precision'>

# %%
def train_rfc(data, top_n):
    top_n_features = mi_scores.sort_values(ascending=False).head(top_n).index.tolist()
    X = data[top_n_features]
    y = data['labels']
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)
    rfc = RandomForestClassifier(n_estimators=500, max_depth=32,max_features=1.0)
    rfc.fit(X_train, y_train)
    y_pred = rfc.predict(X_test)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    return precision, recall, f1, accuracy

# %%
arr = []
for i in range(20,51,1):
    precision, recall, f1, accuracy = train_rfc(data, i)
    print("Performance for RFC Model with Top {} features is precision : {},recall : {}, f1 score : {}, accuracy : {}".format(i, precision, recall, f1,accuracy))
    arr.append([i, precision, recall, f1, accuracy])
# Out:
# Performance for RFC Model with Top 20 features is precision : 0.9692154915590864,recall : 0.9779559118236473, f1 score : 0.97356608478803, accuracy : 0.9735
# Performance for RFC Model with Top 21 features is precision : 0.9634748272458046,recall : 0.9828801611278952, f1 score : 0.9730807577268196, accuracy : 0.973
# Performance for RFC Model with Top 22 features is precision : 0.9683301343570058,recall : 0.9834307992202729, f1 score : 0.9758220502901354, accuracy : 0.975
# Performance for RFC Model with Top 23 features is precision : 0.9715639810426541,recall : 0.9818007662835249, f1 score : 0.9766555502620295, accuracy : 0.9755
# Performance for RFC Model with Top 24 features is precision : 0.9729458917835672,recall : 0.9768611670020121, f1 score : 0.9748995983935743, accuracy : 0.975
# Performance for RFC Model with Top 25 features is precision : 0.9788306451612904,recall : 0.9680957128614157, f1 score : 0.9734335839598998, accuracy : 0.9735
# Performance for RFC Model with Top 26 features is precision : 0.9777553083923155,recall : 0.9708835341365462, f1 score : 0.9743073047858942, accuracy : 0.9745
# Performance for RFC Model with Top 27 features is precision : 0.9778894472361809,recall : 0.972027972027972, f1 score : 0.9749498997995992, accuracy : 0.975
# Performance for RFC Model with Top 28 features is precision : 0.9774288518155054,recall : 0.9822485207100592, f1 score : 0.9798327594687654, accuracy : 0.9795
# Performance for RFC Model with Top 29 features is precision : 0.9734774066797642,recall : 0.9860696517412936, f1 score : 0.9797330696984676, accuracy : 0.9795
# Performance for RFC Model with Top 30 features is precision : 0.9748490945674044,recall : 0.969, f1 score : 0.9719157472417251, accuracy : 0.972
# Performance for RFC Model with Top 31 features is precision : 0.9801255230125523,recall : 0.9770594369134515, f1 score : 0.9785900783289817, accuracy : 0.9795
# Performance for RFC Model with Top 32 features is precision : 0.9708835341365462,recall : 0.9747983870967742, f1 score : 0.9728370221327968, accuracy : 0.973
# Performance for RFC Model with Top 33 features is precision : 0.9821251241310824,recall : 0.9811507936507936, f1 score : 0.9816377171215881, accuracy : 0.9815
# Performance for RFC Model with Top 34 features is precision : 0.9777777777777777,recall : 0.9796708615682478, f1 score : 0.9787234042553191, accuracy : 0.978
# Performance for RFC Model with Top 35 features is precision : 0.9764243614931237,recall : 0.9764243614931237, f1 score : 0.9764243614931237, accuracy : 0.976
# Performance for RFC Model with Top 36 features is precision : 0.9767911200807265,recall : 0.9738430583501007, f1 score : 0.9753148614609571, accuracy : 0.9755
# Performance for RFC Model with Top 37 features is precision : 0.9760717846460618,recall : 0.978021978021978, f1 score : 0.9770459081836327, accuracy : 0.977
# Performance for RFC Model with Top 38 features is precision : 0.9818731117824774,recall : 0.9730538922155688, f1 score : 0.9774436090225563, accuracy : 0.9775
# Performance for RFC Model with Top 39 features is precision : 0.9776699029126213,recall : 0.9738878143133463, f1 score : 0.9757751937984496, accuracy : 0.975
# Performance for RFC Model with Top 40 features is precision : 0.9711934156378601,recall : 0.9752066115702479, f1 score : 0.9731958762886598, accuracy : 0.974
# Performance for RFC Model with Top 41 features is precision : 0.9792079207920792,recall : 0.9840796019900497, f1 score : 0.9816377171215881, accuracy : 0.9815
# Performance for RFC Model with Top 42 features is precision : 0.974721941354904,recall : 0.9776876267748479, f1 score : 0.9762025316455696, accuracy : 0.9765
# Performance for RFC Model with Top 43 features is precision : 0.9736585365853658,recall : 0.9774730656219393, f1 score : 0.9755620723362659, accuracy : 0.975
# Performance for RFC Model with Top 44 features is precision : 0.9757085020242915,recall : 0.9757085020242915, f1 score : 0.9757085020242915, accuracy : 0.976
# Performance for RFC Model with Top 45 features is precision : 0.9794117647058823,recall : 0.9736842105263158, f1 score : 0.9765395894428153, accuracy : 0.976
# Performance for RFC Model with Top 46 features is precision : 0.9848942598187311,recall : 0.9819277108433735, f1 score : 0.9834087481146304, accuracy : 0.9835
# Performance for RFC Model with Top 47 features is precision : 0.9820359281437125,recall : 0.9781312127236581, f1 score : 0.9800796812749004, accuracy : 0.98
# Performance for RFC Model with Top 48 features is precision : 0.9859154929577465,recall : 0.9712586719524281, f1 score : 0.9785322016974538, accuracy : 0.9785
# Performance for RFC Model with Top 49 features is precision : 0.9783889980353635,recall : 0.9812807881773399, f1 score : 0.9798327594687654, accuracy : 0.9795
# Performance for RFC Model with Top 50 features is precision : 0.9747327502429544,recall : 0.9794921875, f1 score : 0.9771066731612275, accuracy : 0.9765

# %%
sns.lineplot(x='num_of_features', y='precision', data=df, label='PrecisionScore')
sns.lineplot(x='num_of_features', y='recall', data=df, label='Recall Score')
sns.lineplot(x='num_of_features', y='f1_score', data=df, label='F1 Score')
sns.lineplot(x='num_of_features', y='accuracy', data=df, label='Acc Score')
# Out:
# <Axes: xlabel='num_of_features', ylabel='precision'>

# %%
top_n_features = mi_scores.sort_values(ascending=False).head(32).index.tolist()
X = data[top_n_features]
y = data['labels']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,shuffle=True)
rfc = RandomForestClassifier(n_estimators=500, max_depth=32, max_features=1.0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)

# %%
print("Performance for RFC Model with Top {} features is precision : {},recall : {}, f1 score : {}, accuracy : {}".format(27, precision, recall, f1,accuracy))
# Out:
# Performance for RFC Model with Top 27 features is precision : 0.9760717846460618,recall : 0.9839195979899498, f1 score : 0.97997997997998, accuracy : 0.98

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      1005
#            1       0.98      0.98      0.98       995
#
#     accuracy                           0.98      2000
#    macro avg       0.98      0.98      0.98      2000
# weighted avg       0.98      0.98      0.98      2000
